# %% [markdown]
# # Seaborn

# %% [markdown]
# # importing packages to seaborn

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # inBuilt data sets

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %%
crash_df = sns.load_dataset('car_crashes')
crash_df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %% [markdown]
# # Distribution plots

# %%
sns.displot(crash_df['not_distracted'])

# %%
sns.displot(crash_df['not_distracted'], kde = True)

# %%
sns.displot(crash_df['not_distracted'], kde = True, bins = 25)

# %%
sns.displot(crash_df['ins_premium'], kde = True)

# %% [markdown]
# # Join plot

# %%
sns.jointplot(x = 'speeding',y = 'alcohol', data = crash_df, kind = 'reg') # reg = regression

# %%
sns.jointplot(x = 'speeding',y = 'alcohol', data = crash_df, kind = 'kde') #kde = kernel density estimation

# %%
sns.jointplot(x = 'speeding',y = 'alcohol', data = crash_df, kind = 'hex')

# %% [markdown]
# # Kde plot

# %%
sns.kdeplot(crash_df['alcohol'])
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# # pair plot

# %%
sns.pairplot(crash_df)

# %%
tips_df = sns.load_dataset('tips')
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips_df = sns.load_dataset('tips')
sns.pairplot(tips_df, hue = 'smoker', palette = 'Blues')

# %% [markdown]
# # rug plots

# %%
sns.rugplot(tips_df['tip'])
# Out:
# <AxesSubplot:xlabel='tip'>

# %% [markdown]
# # styling

# %%
sns.set_style('white')

sns.jointplot(x = 'speeding',y = 'alcohol', data = crash_df, kind = 'reg')

# %%
sns.set_style('white')

plt.figure(figsize = (4,4))

sns.jointplot(x = 'speeding',y = 'alcohol', data = crash_df, kind = 'reg')

# %%
sns.set_style('darkgrid') #in place of ' darkgrid we can also give : whitegrid,dark,ticks

plt.figure(figsize = (4,4))

sns.jointplot(x = 'speeding',y = 'alcohol', data = crash_df, kind = 'reg')

# %%
sns.set_style('darkgrid') #in place of ' darkgrid we can also give : whitegrid,dark,ticks

plt.figure(figsize = (4,4))
sns.set_context('paper', font_scale = 1.4)#in place of ' paper' we can also give : talk,poster

sns.jointplot(x = 'speeding',y = 'alcohol', data = crash_df, kind = 'reg')

# %%
sns.set_style('ticks') #in place of ' darkgrid we can also give : whitegrid,dark,ticks

plt.figure(figsize = (4,4))
sns.set_context('paper', font_scale = 1.4)#in place of ' paper' we can also give : talk,poster

sns.jointplot(x = 'speeding',y = 'alcohol', data = crash_df, kind = 'reg')
sns.despine(left = False)

# %%
sns.set_style('ticks') #in place of ' darkgrid we can also give : whitegrid,dark,ticks

plt.figure(figsize = (4,4))
sns.set_context('paper', font_scale = 1.4)#in place of ' paper' we can also give : talk,poster

sns.jointplot(x = 'speeding',y = 'alcohol', data = crash_df, kind = 'reg')
sns.despine(left = True)

# %%
sns.set_style('ticks') #in place of ' darkgrid we can also give : whitegrid,dark,ticks

plt.figure(figsize = (4,4))
sns.set_context('paper', font_scale = 1.4)#in place of ' paper' we can also give : talk,poster

sns.jointplot(x = 'speeding',y = 'alcohol', data = crash_df, kind = 'reg')
sns.despine(left = True, bottom = True)

# %% [markdown]
# # Categorical plots

# %% [markdown]
# ##### Bar plots

# %%
sns.barplot(x = 'sex', y = 'total_bill', data = tips_df, estimator = np.median)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# # Count plot

# %%
sns.countplot(x = 'sex', data = tips_df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# # Box plot

# %%
sns.boxplot(x = 'day', y = 'total_bill', data = tips_df, hue = 'sex')
plt.legend(loc = 0)

# %% [markdown]
# # violin plot

# %%
sns.violinplot(x = 'day', y = 'total_bill', data = tips_df, hue = 'sex', split = True)
plt.legend(loc = 0)

# %% [markdown]
# # Strip plot

# %%
plt.figure(figsize = (8,5))
sns.stripplot(x = 'day', y = 'total_bill', data = tips_df )
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
plt.figure(figsize = (8,5))
sns.stripplot(x = 'day', y = 'total_bill', data = tips_df, jitter = True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
plt.figure(figsize = (8,5))
sns.stripplot(x = 'day', y = 'total_bill', data = tips_df, jitter = True, hue = 'sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
plt.figure(figsize = (8,5))
sns.stripplot(x = 'day', y = 'total_bill', data = tips_df, jitter = True, hue = 'sex', dodge = True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Swarm plot

# %%
sns.violinplot(x = 'day', y ='total_bill', data = tips_df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x = 'day', y ='total_bill', data = tips_df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # paletts

# %%
plt.figure(figsize = (8,5))

sns.set_style('dark')
sns.set_context('talk')
sns.stripplot(x = 'day', y = 'total_bill', data = tips_df, hue ='sex' )
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
plt.figure(figsize = (8,5))

sns.set_style('dark')
sns.set_context('talk')
sns.stripplot(x = 'day', y = 'total_bill', data = tips_df, hue ='sex', palette = 'magma' )
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
plt.figure(figsize = (8,5))

sns.set_style('dark')
sns.set_context('talk')
sns.stripplot(x = 'day', y = 'total_bill', data = tips_df, hue ='sex', palette = 'afmhot' )
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Matrix plots

# %% [markdown]
# ### Heatmaps

# %%
plt.figure(figsize = (8,6))
sns.set_context('paper', font_scale = 1.4)

crash_mx = crash_df.corr()

sns.heatmap(crash_mx, annot = True, cmap = 'Blues')
# Out:
# <AxesSubplot:>

# %%
flights = sns.load_dataset('flights')
flights = flights.pivot_table(index = 'month', columns = 'year', values = 'passengers' )
sns.heatmap(flights, cmap = 'Blues')
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
flights = sns.load_dataset('flights')
flights = flights.pivot_table(index = 'month', columns = 'year', values = 'passengers' )
sns.heatmap(flights, cmap = 'Blues', linecolor = 'white', linewidth = 1)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %% [markdown]
# # Cluster map

# %%
iris = sns.load_dataset('iris')

species = iris.pop('species')
sns.clustermap(iris)

# %%
sns.clustermap(flights, cmap = 'Blues', standard_scale = 1, linecolor = 'white', linewidth = 1)

# %% [markdown]
# # Pair Grid

# %%
iris = sns.load_dataset('iris')
iris_g = sns.PairGrid(iris, hue ='species')
iris_g.map(plt.scatter)

# %%
iris = sns.load_dataset('iris')
iris_g = sns.PairGrid(iris, hue ='species')
iris_g.map(plt.scatter)
iris_g.map_diag(plt.hist)

# %%
iris = sns.load_dataset('iris')
iris_g = sns.PairGrid(iris, hue ='species')

iris_g.map_diag(plt.hist)
iris_g.map_offdiag(plt.scatter)

# %%
iris = sns.load_dataset('iris')
iris_g = sns.PairGrid(iris, hue ='species')

iris_g.map_diag(plt.hist)
#iris_g.map_offdiag(plt.scatter)
iris_g.map_upper(plt.scatter)
iris_g.map_lower(sns.kdeplot)

# %%
iris = sns.load_dataset('iris')
iris_g = sns.PairGrid(iris, hue ='species')

iris_g.map_diag(plt.hist)
#iris_g.map_offdiag(plt.scatter)
iris_g.map_upper(plt.scatter)
iris_g.map_lower(sns.kdeplot)
iris_g = sns.PairGrid(iris, hue = 'species', x_vars = ['sepal_length', 'sepal_width'],
                      y_vars = ["petal_length", 'petal_width'])
iris_g.map(plt.scatter)
iris_g.add_legend()

# %% [markdown]
# # Facet Grid

# %%
tips_fg = sns.FacetGrid(tips_df, col = 'time', row = 'smoker')

# %%
tips_fg = sns.FacetGrid(tips_df, col = 'time', row = 'smoker')
tips_fg.map(plt.hist, 'total_bill', bins = 8)

# %%
tips_fg = sns.FacetGrid(tips_df, col = 'time', row = 'smoker')
tips_fg.map(plt.scatter, 'total_bill', 'tip')

# %%
tips_fg = sns.FacetGrid(tips_df, col = 'time', hue = 'smoker', height = 4, aspect = 1.3, col_order =['Dinner', 'Lunch'],  palette = 'Set1')
tips_fg.map(plt.scatter, 'total_bill','tip', edgecolor = 'w')

# %%
kws = dict(s = 50, linewidth = 5, edgecolor = 'c')
tips_fg = sns.FacetGrid(tips_df, col = 'sex', hue = 'smoker', height = 4, aspect = 1.3,
                       hue_order = ['Yes', 'No'], hue_kws = dict(marker = ['^','v']))
tips_fg.map(plt.scatter, 'total_bill', 'tip', **kws)

# %%
att_df = sns.load_dataset('attention')
att_fg = sns.FacetGrid(att_df, col = 'subject', col_wrap = 5, height = 1.5)
att_fg.map(plt.plot, 'solutions', 'score', marker = '.')

# %% [markdown]
# # Regression plots

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize = (8, 6))
sns.set_context('paper', font_scale = 1.4)
sns.lmplot(x = 'total_bill', y = 'tip', hue = 'sex', data = tips_df, markers = ['o', '^'],
          scatter_kws = {'s' : 100, 'linewidth' : 0.5, 'edgecolor': 'w'})

# %%
sns.set_context('paper', font_scale = 1.4)
sns.lmplot(x = 'total_bill', y = 'tip', col = 'sex', row = 'time', data = tips_df, height = 4, aspect = 0.6 )
